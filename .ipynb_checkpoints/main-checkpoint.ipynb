# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('rnn_lstm.xlsx')
df.head()
# Out:
#                   id  likesCount  \
# 0  17988118445479198           0
# 1  17995515296305509           0
# 2  17975784647410597           0
# 3  18375946198053653           0
# 4  17965259663603317           0
#
#                                   ownerProfilePicUrl         ownerUsername  \
# 0  https://scontent-iad3-2.cdninstagram.com/v/t51...            frank21327
# 1  https://scontent-iad3-1.cdninstagram.com/v/t51...  lawrence____larry.10
# 2  https://scontent-iad3-1.cdninstagram.com/v/t51...            mari_o9754
# 3  https://scontent-iad3-2.cdninstagram.com/v/t51...     howard____thopson
# 4  https://scontent-iad3-1.cdninstagram.com/v/t51...          elly_x_elias
#
#                                     postUrl  Unnamed: 5  \
# 0  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 1  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 2  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 3  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 4  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
#
#                                                 text Unnamed: 7  \
# 0  I was afraid to start but when I did I was so ...       Scam
# 1  I’m paying 5 grands to the first 7 people to m...       Scam
# 2  @madison_exchange_1 I was referred to this pla...       Scam
# 3  PAYING 5 GRAND TO The First 5 People To Messag...       Scam
# 4  I never believe I could get my partner back. I...       Scam
#
#                   timestamp
# 0  2023-08-01T00:02:06.000Z
# 1  2023-08-01T00:02:44.000Z
# 2  2023-08-01T00:03:38.000Z
# 3  2023-08-01T00:04:17.000Z
# 4  2023-08-01T00:04:57.000Z

# %%
columns = df.columns
columns
# Out:
# Index(['id', 'likesCount', 'ownerProfilePicUrl', 'ownerUsername', 'postUrl',
#        'Unnamed: 5', 'text', 'Unnamed: 7', 'timestamp'],
#       dtype='object')

# %%
# renaming the unnamed 7 column as the label column

df.rename(columns={'Unnamed: 7':'label'}, inplace=True)
df.head()
# Out:
#                   id  likesCount  \
# 0  17988118445479198           0
# 1  17995515296305509           0
# 2  17975784647410597           0
# 3  18375946198053653           0
# 4  17965259663603317           0
#
#                                   ownerProfilePicUrl         ownerUsername  \
# 0  https://scontent-iad3-2.cdninstagram.com/v/t51...            frank21327
# 1  https://scontent-iad3-1.cdninstagram.com/v/t51...  lawrence____larry.10
# 2  https://scontent-iad3-1.cdninstagram.com/v/t51...            mari_o9754
# 3  https://scontent-iad3-2.cdninstagram.com/v/t51...     howard____thopson
# 4  https://scontent-iad3-1.cdninstagram.com/v/t51...          elly_x_elias
#
#                                     postUrl  Unnamed: 5  \
# 0  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 1  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 2  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 3  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
# 4  https://www.instagram.com/p/CvYY_VxNxNr/         NaN
#
#                                                 text label  \
# 0  I was afraid to start but when I did I was so ...  Scam
# 1  I’m paying 5 grands to the first 7 people to m...  Scam
# 2  @madison_exchange_1 I was referred to this pla...  Scam
# 3  PAYING 5 GRAND TO The First 5 People To Messag...  Scam
# 4  I never believe I could get my partner back. I...  Scam
#
#                   timestamp
# 0  2023-08-01T00:02:06.000Z
# 1  2023-08-01T00:02:44.000Z
# 2  2023-08-01T00:03:38.000Z
# 3  2023-08-01T00:04:17.000Z
# 4  2023-08-01T00:04:57.000Z

# %%
df_req = df[['text', 'label']]
df_req.head()
# Out:
#                                                 text label
# 0  I was afraid to start but when I did I was so ...  Scam
# 1  I’m paying 5 grands to the first 7 people to m...  Scam
# 2  @madison_exchange_1 I was referred to this pla...  Scam
# 3  PAYING 5 GRAND TO The First 5 People To Messag...  Scam
# 4  I never believe I could get my partner back. I...  Scam

# %%
df_req.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    1964 non-null   object
#  1   label   274 non-null    object
# dtypes: object(2)
# memory usage: 34.5+ KB

# %%
df_req['label'][[df_req['label'] != 'Scam']] = 'not scam'
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1084         try:
# -> 1085             self._set_with_engine(key, value)
#    1086         except (KeyError, ValueError):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1145     def _set_with_engine(self, key, value) -> None:
# -> 1146         loc = self.index.get_loc(key)
#    1147
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
# --> 388             self._check_indexing_error(key)
#     389             raise KeyError(key)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _check_indexing_error(self, key)
#    5650             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5651             raise InvalidIndexError(key)
#    5652
#
# InvalidIndexError: [0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2194     True
# 2195     True
# 2196     True
# 2197     True
# 2198     True
# Name: label, Length: 2199, dtype: bool]
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18460\2602440845.py in <module>
# ----> 1 df_req['label'][[df_req['label'] != 'Scam']] = 'not scam'
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1138
#    1139             else:
# -> 1140                 self._set_with(key, value)
#    1141
#    1142         if cacher_needs_updating:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _set_with(self, key, value)
#    1169                 self._set_values(key, value)
#    1170         else:
# -> 1171             self.loc[key] = value
#    1172
#    1173     def _set_labels(self, key, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     710         else:
#     711             key = com.apply_if_callable(key, self.obj)
# --> 712         indexer = self._get_setitem_indexer(key)
#     713         self._has_valid_setitem_indexer(key)
#     714
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     664             return list(key)
#     665
# --> 666         return self._convert_to_indexer(key, axis=0)
#     667
#     668     def _ensure_listlike_indexer(self, key, axis=None, value=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis)
#    1292                 return inds
#    1293             else:
# -> 1294                 return self._get_listlike_indexer(key, axis)[1]
#    1295         else:
#    1296             try:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1328         axis_name = self.obj._get_axis_name(axis)
#    1329
# -> 1330         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1331
#    1332         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index([(False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, ...)], dtype='object')] are in the [index]"
